# %%
# install rdkit  
# !wget -c https://repo.continuum.io/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local
# !conda install -q -y -c rdkit rdkit python=3.7
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
import pprint     
pprint.pprint(sys.path)
# !python -c "import site; print (site.getsitepackages())"
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - _openmp_mutex==4.5=1_gnu
#     - brotlipy==0.7.0=py39h27cfd23_1003
#     - ca-certificates==2022.3.29=h06a4308_1
#     - certifi==2021.10.8=py39h06a4308_2
#     - cffi==1.15.0=py39hd667e15_1
#     - charset-normalizer==2.0.4=pyhd3eb1b0_0
#     - colorama==0.4.4=pyhd3eb1b0_0
#     - conda-content-trust==0.1.1=pyhd3eb1b0_0
#     - conda-package-handling==1.8.1=py39h7f8727e_0
#     - conda==4.12.0=py39h06a4308_0
#     - cryptography==36.0.0=py39h9ce1e76_0
#     - idna==3.3=pyhd3eb1b0_0
#     - ld_impl_linux-64==2.35.1=h7274673_9
#     - libffi==3.3=he6710b0_2
#     - libgcc-ng==9.3.0=h5101ec6_17
#     - libgomp==9.3.0=h5101ec6_17
#     - libstdcxx-ng==9.3.0=hd4cf53a_17
#     - ncurses==6.3=h7f8727e_2
#     - openssl==1.1.1n=h7f8727e_0
#     - pip==21.2.4=py39h06a4308_0
#     - pycosat==0.6.3=py39h27cfd23_0
#     - pycparser==2.21=pyhd3eb1b0_0
#     - pyopenssl==22.0.0=pyhd3eb1b0_0
#     - pysocks==1.7.1=py39h06a4308_0
#     - python==3.9.12=h12debd9_0
#     - readline==8.1.2=h7f8727e_1
#     - requests==2.27.1=pyhd3eb1b0_0
#     - ruamel_yaml==0.15.100=py39h27cfd23_0
#     - setuptools==61.2.0=py39h06a4308_0
#     - six==1.16.0=pyhd3eb1b0_1
#     - sqlite==3.38.2=hc218d9a_0
#     - tk==8.6.11=h1ccaba5_0
#     - tqdm==4.63.0=pyhd3eb1b0_0
#     - tzdata==2022a=hda174b7_0
#     - urllib3==1.26.8=pyhd3eb1b0_0
#     - wheel==0.37.1=pyhd3eb1b0_0
#     - xz==5.2.5=h7b6447c_0
#     - yaml==0.2.5=h7b6447c_0
#     - zlib==1.2.12=h7f8727e_1
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-4.5-1_gnu
#   brotlipy           pkgs/main/linux-64::brotlipy-0.7.0-py39h27cfd23_1003
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2022.3.29-h06a4308_1
#   certifi            pkgs/main/linux-64::certifi-2021.10.8-py39h06a4308_2
#   cffi               pkgs/main/linux-64::cffi-1.15.0-py39hd667e15_1
#   charset-normalizer pkgs/main/noarch::charset-normalizer-2.0.4-pyhd3eb1b0_0
#   colorama           pkgs/main/noarch::colorama-0.4.4-pyhd3eb1b0_0
#   conda              pkgs/main/linux-64::conda-4.12.0-py39h06a4308_0
#   conda-content-tru~ pkgs/main/noarch::conda-content-trust-0.1.1-pyhd3eb1b0_0
#   conda-package-han~ pkgs/main/linux-64::conda-package-handling-1.8.1-py39h7f8727e_0
#   cryptography       pkgs/main/linux-64::cryptography-36.0.0-py39h9ce1e76_0
#   idna               pkgs/main/noarch::idna-3.3-pyhd3eb1b0_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.35.1-h7274673_9
#   libffi             pkgs/main/linux-64::libffi-3.3-he6710b0_2
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-9.3.0-h5101ec6_17
#   libgomp            pkgs/main/linux-64::libgomp-9.3.0-h5101ec6_17
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-9.3.0-hd4cf53a_17
#   ncurses            pkgs/main/linux-64::ncurses-6.3-h7f8727e_2
#   openssl            pkgs/main/linux-64::openssl-1.1.1n-h7f8727e_0
#   pip                pkgs/main/linux-64::pip-21.2.4-py39h06a4308_0
#   pycosat            pkgs/main/linux-64::pycosat-0.6.3-py39h27cfd23_0
#   pycparser          pkgs/main/noarch::pycparser-2.21-pyhd3eb1b0_0
#   pyopenssl          pkgs/main/noarch::pyopenssl-22.0.0-pyhd3eb1b0_0
#   pysocks            pkgs/main/linux-64::pysocks-1.7.1-py39h06a4308_0
#   python             pkgs/main/linux-64::python-3.9.12-h12debd9_0
#   readline           pkgs/main/linux-64::readline-8.1.2-h7f8727e_1
#   requests           pkgs/main/noarch::requests-2.27.1-pyhd3eb1b0_0
#   ruamel_yaml        pkgs/main/linux-64::ruamel_yaml-0.15.100-py39h27cfd23_0
#   setuptools         pkgs/main/linux-64::setuptools-61.2.0-py39h06a4308_0
#   six                pkgs/main/noarch::six-1.16.0-pyhd3eb1b0_1
#   sqlite             pkgs/main/linux-64::sqlite-3.38.2-hc218d9a_0
#   tk                 pkgs/main/linux-64::tk-8.6.11-h1ccaba5_0
#   tqdm               pkgs/main/noarch::tqdm-4.63.0-pyhd3eb1b0_0
#   tzdata             pkgs/main/noarch::tzdata-2022a-hda174b7_0
#   urllib3            pkgs/main/noarch::urllib3-1.26.8-pyhd3eb1b0_0
#   wheel              pkgs/main/noarch::wheel-0.37.1-pyhd3eb1b0_0
#   xz                 pkgs/main/linux-64::xz-5.2.5-h7b6447c_0
#   yaml               pkgs/main/linux-64::yaml-0.2.5-h7b6447c_0
#   zlib               pkgs/main/linux-64::zlib-1.2.12-h7f8727e_1
#
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - python=3.7
#     - rdkit
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |              mkl           6 KB
#     bottleneck-1.3.4           |   py37hce1f21e_0         126 KB
#     brotlipy-0.7.0             |py37h27cfd23_1003         320 KB
#     bzip2-1.0.8                |       h7b6447c_0          78 KB
#     ca-certificates-2022.07.19 |       h06a4308_0         124 KB
#     cairo-1.16.0               |       h19f5f5c_2         1.1 MB
#     certifi-2022.6.15          |   py37h06a4308_0         153 KB
#     cffi-1.15.0                |   py37hd667e15_1         222 KB
#     conda-4.14.0               |   py37h06a4308_0         909 KB
#     conda-package-handling-1.8.1|   py37h7f8727e_0         889 KB
#     cryptography-37.0.1        |   py37h9ce1e76_0         1.3 MB
#     cytoolz-0.11.0             |   py37h7b6447c_0         328 KB
#     fontconfig-2.13.1          |       h6c09931_0         250 KB
#     freetype-2.11.0            |       h70c0345_0         618 KB
#     giflib-5.2.1               |       h7b6447c_0          78 KB
#     glib-2.69.1                |       h4ff587b_1         1.7 MB
#     icu-58.2                   |       he6710b0_3        10.5 MB
#     intel-openmp-2021.4.0      |    h06a4308_3561         4.2 MB
#     jpeg-9e                    |       h7f8727e_0         240 KB
#     lcms2-2.12                 |       h3be6417_0         312 KB
#     libboost-1.73.0            |      h28710b8_12        13.8 MB
#     libpng-1.6.37              |       hbc83047_0         278 KB
#     libtiff-4.2.0              |       h2818925_1         452 KB
#     libuuid-1.0.3              |       h7f8727e_2          17 KB
#     libwebp-1.2.2              |       h55f646e_0          80 KB
#     libwebp-base-1.2.2         |       h7f8727e_0         440 KB
#     libxcb-1.15                |       h7f8727e_0         505 KB
#     libxml2-2.9.14             |       h74e7548_0         718 KB
#     lz4-c-1.9.3                |       h295c915_1         185 KB
#     mkl-2021.4.0               |     h06a4308_640       142.6 MB
#     mkl-service-2.4.0          |   py37h7f8727e_0          56 KB
#     mkl_fft-1.3.1              |   py37hd3c417c_0         172 KB
#     mkl_random-1.2.2           |   py37h51133e4_0         287 KB
#     numexpr-2.8.1              |   py37h6abb31d_0         123 KB
#     numpy-1.21.5               |   py37he7a7128_2          10 KB
#     numpy-base-1.21.5          |   py37hf524024_2         4.8 MB
#     openssl-1.1.1q             |       h7f8727e_0         2.5 MB
#     packaging-21.3             |     pyhd3eb1b0_0          36 KB
#     pandas-1.3.5               |   py37h8c16a72_0         9.3 MB
#     pcre-8.45                  |       h295c915_0         207 KB
#     pillow-9.0.1               |   py37h22f2fdc_0         652 KB
#     pip-22.1.2                 |   py37h06a4308_0         2.4 MB
#     pixman-0.40.0              |       h7f8727e_1         373 KB
#     py-boost-1.73.0            |  py37h51133e4_12         195 KB
#     pycosat-0.6.3              |   py37h27cfd23_0          81 KB
#     pyparsing-3.0.9            |   py37h06a4308_0         150 KB
#     pysocks-1.7.1              |           py37_1          27 KB
#     python-3.7.13              |       h12debd9_0        46.2 MB
#     python-dateutil-2.8.2      |     pyhd3eb1b0_0         233 KB
#     pytz-2022.1                |   py37h06a4308_0         196 KB
#     rdkit-2020.09.1.0          |   py37hd50e099_1        25.8 MB  rdkit
#     ruamel_yaml-0.15.100       |   py37h27cfd23_0         253 KB
#     setuptools-63.4.1          |   py37h06a4308_0         1.1 MB
#     toolz-0.11.2               |     pyhd3eb1b0_0          49 KB
#     zstd-1.5.2                 |       ha4553b6_0         488 KB
#     ------------------------------------------------------------
#                                            Total:       277.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/linux-64::blas-1.0-mkl
#   bottleneck         pkgs/main/linux-64::bottleneck-1.3.4-py37hce1f21e_0
#   bzip2              pkgs/main/linux-64::bzip2-1.0.8-h7b6447c_0
#   cairo              pkgs/main/linux-64::cairo-1.16.0-h19f5f5c_2
#   cytoolz            pkgs/main/linux-64::cytoolz-0.11.0-py37h7b6447c_0
#   fontconfig         pkgs/main/linux-64::fontconfig-2.13.1-h6c09931_0
#   freetype           pkgs/main/linux-64::freetype-2.11.0-h70c0345_0
#   giflib             pkgs/main/linux-64::giflib-5.2.1-h7b6447c_0
#   glib               pkgs/main/linux-64::glib-2.69.1-h4ff587b_1
#   icu                pkgs/main/linux-64::icu-58.2-he6710b0_3
#   intel-openmp       pkgs/main/linux-64::intel-openmp-2021.4.0-h06a4308_3561
#   jpeg               pkgs/main/linux-64::jpeg-9e-h7f8727e_0
#   lcms2              pkgs/main/linux-64::lcms2-2.12-h3be6417_0
#   libboost           pkgs/main/linux-64::libboost-1.73.0-h28710b8_12
#   libpng             pkgs/main/linux-64::libpng-1.6.37-hbc83047_0
#   libtiff            pkgs/main/linux-64::libtiff-4.2.0-h2818925_1
#   libuuid            pkgs/main/linux-64::libuuid-1.0.3-h7f8727e_2
#   libwebp            pkgs/main/linux-64::libwebp-1.2.2-h55f646e_0
#   libwebp-base       pkgs/main/linux-64::libwebp-base-1.2.2-h7f8727e_0
#   libxcb             pkgs/main/linux-64::libxcb-1.15-h7f8727e_0
#   libxml2            pkgs/main/linux-64::libxml2-2.9.14-h74e7548_0
#   lz4-c              pkgs/main/linux-64::lz4-c-1.9.3-h295c915_1
#   mkl                pkgs/main/linux-64::mkl-2021.4.0-h06a4308_640
#   mkl-service        pkgs/main/linux-64::mkl-service-2.4.0-py37h7f8727e_0
#   mkl_fft            pkgs/main/linux-64::mkl_fft-1.3.1-py37hd3c417c_0
#   mkl_random         pkgs/main/linux-64::mkl_random-1.2.2-py37h51133e4_0
#   numexpr            pkgs/main/linux-64::numexpr-2.8.1-py37h6abb31d_0
#   numpy              pkgs/main/linux-64::numpy-1.21.5-py37he7a7128_2
#   numpy-base         pkgs/main/linux-64::numpy-base-1.21.5-py37hf524024_2
#   packaging          pkgs/main/noarch::packaging-21.3-pyhd3eb1b0_0
#   pandas             pkgs/main/linux-64::pandas-1.3.5-py37h8c16a72_0
#   pcre               pkgs/main/linux-64::pcre-8.45-h295c915_0
#   pillow             pkgs/main/linux-64::pillow-9.0.1-py37h22f2fdc_0
#   pixman             pkgs/main/linux-64::pixman-0.40.0-h7f8727e_1
#   py-boost           pkgs/main/linux-64::py-boost-1.73.0-py37h51133e4_12
#   pyparsing          pkgs/main/linux-64::pyparsing-3.0.9-py37h06a4308_0
#   python-dateutil    pkgs/main/noarch::python-dateutil-2.8.2-pyhd3eb1b0_0
#   pytz               pkgs/main/linux-64::pytz-2022.1-py37h06a4308_0
#   rdkit              rdkit/linux-64::rdkit-2020.09.1.0-py37hd50e099_1
#   toolz              pkgs/main/noarch::toolz-0.11.2-pyhd3eb1b0_0
#   zstd               pkgs/main/linux-64::zstd-1.5.2-ha4553b6_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2022.3.29-h06a4308_1 --> 2022.07.19-h06a4308_0
#   certifi                          2021.10.8-py39h06a4308_2 --> 2022.6.15-py37h06a4308_0
#   conda                               4.12.0-py39h06a4308_0 --> 4.14.0-py37h06a4308_0
#   cryptography                        36.0.0-py39h9ce1e76_0 --> 37.0.1-py37h9ce1e76_0
#   openssl                                 1.1.1n-h7f8727e_0 --> 1.1.1q-h7f8727e_0
#   pip                                 21.2.4-py39h06a4308_0 --> 22.1.2-py37h06a4308_0
#   pysocks                              1.7.1-py39h06a4308_0 --> 1.7.1-py37_1
#   setuptools                          61.2.0-py39h06a4308_0 --> 63.4.1-py37h06a4308_0
#
# The following packages will be DOWNGRADED:
#
#   brotlipy                          0.7.0-py39h27cfd23_1003 --> 0.7.0-py37h27cfd23_1003
#   cffi                                1.15.0-py39hd667e15_1 --> 1.15.0-py37hd667e15_1
#   conda-package-han~                   1.8.1-py39h7f8727e_0 --> 1.8.1-py37h7f8727e_0
#   pycosat                              0.6.3-py39h27cfd23_0 --> 0.6.3-py37h27cfd23_0
#   python                                  3.9.12-h12debd9_0 --> 3.7.13-h12debd9_0
#   ruamel_yaml                       0.15.100-py39h27cfd23_0 --> 0.15.100-py37h27cfd23_0
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# ['/content',
#  '/env/python',
#  '/usr/lib/python37.zip',
#  '/usr/lib/python3.7',
#  '/usr/lib/python3.7/lib-dynload',
#  '',
#  '/usr/local/lib/python3.7/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.7/dist-packages/IPython/extensions',
#  '/root/.ipython',
#  '/usr/local/lib/python3.7/site-packages/']
# ['/usr/local/lib/python3.7/site-packages']

# %%
from rdkit import Chem
from rdkit.Chem import rdchem
import re
Chiral = {"CHI_UNSPECIFIED":0,  "CHI_TETRAHEDRAL_CW":1, "CHI_TETRAHEDRAL_CCW":2, "CHI_OTHER":3}

Hybridization = {"UNSPECIFIED":0, "S":1, "SP":2, "SP2":3, "SP3":4, "SP3D":5, "SP3D2":6, "OTHER":7}

atomInfo = 21
structInfo = 21
lensize= atomInfo + structInfo

H_Vector = [0]*atomInfo
H_Vector[0]= 1

lowerReg = re.compile(r'^[a-z]+$')
def islower(s):
    return lowerReg.match(s) is not None

upperReg = re.compile(r'^[A-Z]+$')
def isupper(s):
    return upperReg.match(s) is not None

def calc_atom_feature(atom):
    
    if atom.GetSymbol() == 'H':   feature = [1,0,0,0,0]
    elif atom.GetSymbol() == 'C': feature = [0,1,0,0,0]
    elif atom.GetSymbol() == 'O': feature = [0,0,1,0,0]
    elif atom.GetSymbol() == 'N': feature = [0,0,0,1,0]
    else: feature = [0,0,0,0,1]
        
    feature.append(atom.GetTotalNumHs()/8)
    feature.append(atom.GetTotalDegree()/4)
    feature.append(atom.GetFormalCharge()/8)
    feature.append(atom.GetTotalValence()/8)
    feature.append(atom.IsInRing()*1)
    feature.append(atom.GetIsAromatic()*1)

    f =  [0]*(len(Chiral)-1)
    if Chiral.get(str(atom.GetChiralTag()), 0) != 0:
        f[Chiral.get(str(atom.GetChiralTag()), 0)] = 1
    feature.extend(f)

    f =  [0]*(len(Hybridization)-1)
    if Hybridization.get(str(atom.GetHybridization()), 0) != 0:
        f[Hybridization.get(str(atom.GetHybridization()), 0)] = 1
    feature.extend(f)
    
    return(feature)


def calc_structure_feature(c,flag,label):
    feature = [0]*structInfo

    if c== '(' :
        feature[0] = 1
        flag = 0
    elif c== ')' :
        feature[1] = 1
        flag = 0
    elif c== '[' :
        feature[2] = 1
        flag = 0
    elif c== ']' :
        feature[3] = 1
        flag = 0
    elif c== '.' :
        feature[4] = 1
        flag = 0
    elif c== ':' :
        feature[5] = 1
        flag = 0
    elif c== '=' :
        feature[6] = 1
        flag = 0
    elif c== '#' :
        feature[7] = 1
        flag = 0
    elif c== '\\':
        feature[8] = 1
        flag = 0
    elif c== '/' :
        feature[9] = 1
        flag = 0  
    elif c== '@' :
        feature[10] = 1
        flag = 0
    elif c== '+' :
        feature[11] = 1
        flag = 1
    elif c== '-' :
        feature[12] = 1
        flag = 1
    elif c.isdigit() == True:
        if flag == 0:
            if c in label:
                feature[20] = 1
            else:
                label.append(c)
                feature[19] = 1
        else:
            feature[int(c)-1+12] = 1
            flag = 0
    return(feature,flag,label)


def calc_featurevector(mol, smiles,atomsize):
    flag = 0
    label = []
    molfeature=[]
    idx = 0
    j = 0
            
    for c in smiles:
        if islower(c) == True: continue
        elif isupper(c) == True:
            if c == 'H':
                molfeature.extend(H_Vector)
            else:
                molfeature.extend(calc_atom_feature(rdchem.Mol.GetAtomWithIdx(mol, idx)))
                idx = idx + 1
            molfeature.extend([0]*structInfo)
            j = j +1
            
        else:   
            molfeature.extend([0]*atomInfo)
            f,flag,label = calc_structure_feature(c,flag,label)
            molfeature.extend(f)
            j = j +1

    #0-Padding
    molfeature.extend([0]*(atomsize-j)*lensize)        
    return(molfeature)


def mol_to_feature(mol,n,atomsize):
    try: defaultSMILES = Chem.MolToSmiles(mol, kekuleSmiles=False, isomericSmiles=True, rootedAtAtom=int(n))
    except: defaultSMILES = Chem.MolToSmiles(mol, kekuleSmiles=False, isomericSmiles=True)
    try: isomerSMILES = Chem.MolToSmiles(mol, kekuleSmiles=True, isomericSmiles=True, rootedAtAtom=int(n))
    except: isomerSMILES = Chem.MolToSmiles(mol, kekuleSmiles=True, isomericSmiles=True)
    return calc_featurevector(Chem.MolFromSmiles(defaultSMILES), isomerSMILES,atomsize)

def mol_to_allSMILESfeature(mol, atomsize):
    idx, features =0,  []
    while idx < mol.GetNumAtoms():
        try: defaultSMILES = Chem.MolToSmiles(mol, kekuleSmiles=False, isomericSmiles=True, rootedAtAtom=int(idx))
        except: break
        isomerSMILES = Chem.MolToSmiles(mol, kekuleSmiles=True, isomericSmiles=True, rootedAtAtom=int(idx))
        features.append(calc_featurevector(Chem.MolFromSmiles(defaultSMILES), isomerSMILES,atomsize))
        idx = idx + 1
    return(features)

# %%
import pandas as pd
df = pd.read_csv('top_70_MOAs.txt', sep = '\t')
df
# Out:
#                                                  SMILES  \
# 0                       Oc1ccc(CCNCC2CCc3ccccc3C2=O)cc1
# 1                  OC(CNCCNC(=O)Nc1ccccc1)COc1ccccc1C#N
# 2           O=C1Nc2ccccc2C2=NC(CN3CCN(CC3)c3ccccc3)CN12
# 3            O=C(NC1CCN(CCc2c[nH]c3ccccc23)CC1)c1ccccc1
# 4     O[C@H](CNC[C@@H](O)[C@@H]1CCc2cc(F)ccc2O1)[C@H...
# ...                                                 ...
# 2312  CCn1c(nc2c(ncc(OC[C@H]3CCCNC3)c12)C#CC(C)(C)O)...
# 2313                CCN(CC)CCCCN1c2ccccc2Oc2ccc(Cl)cc12
# 2314      CCCCCCCCCCCCCCCCCCOP(O)(=O)OC1CC[N+](C)(C)CC1
# 2315  Cc1n[nH]c2ccc(cc12)-c1cncc(OC[C@@H](N)Cc2ccccc...
# 2316  CC(C)NC[C@@H](C(=O)N1CCN(CC1)c1ncnc2[C@@H](O)C...
#
#                                  MOA
# 0     adrenergic receptor antagonist
# 1     adrenergic receptor antagonist
# 2     adrenergic receptor antagonist
# 3     adrenergic receptor antagonist
# 4     adrenergic receptor antagonist
# ...                              ...
# 2312                   AKT inhibitor
# 2313                   AKT inhibitor
# 2314                   AKT inhibitor
# 2315                   AKT inhibitor
# 2316                   AKT inhibitor
#
# [2317 rows x 2 columns]

# %%
# check the duplicates 
for i in df.SMILES.tolist():
  if df.SMILES.tolist().count(i) != 1:
    print(i)

# %%
MOA_class_dictionary =  {'AKT inhibitor': 4,
 'ATPase inhibitor': 56,
 'Aurora kinase inhibitor': 16,
 'CC chemokine receptor antagonist': 33,
 'CDK inhibitor': 18,
 'DNA inhibitor': 63,
 'DNA synthesis inhibitor': 26,
 'EGFR inhibitor': 53,
 'GABA receptor antagonist': 49,
 'HCV inhibitor': 0,
 'HDAC inhibitor': 22,
 'HSP inhibitor': 6,
 'JAK inhibitor': 27,
 'MEK inhibitor': 37,
 'NFkB pathway inhibitor': 3,
 'PARP inhibitor': 43,
 'PI3K inhibitor': 51,
 'PPAR receptor agonist': 58,
 'acetylcholine receptor agonist': 44,
 'acetylcholine receptor antagonist': 36,
 'acetylcholinesterase inhibitor': 19,
 'adenosine receptor agonist': 45,
 'adenosine receptor antagonist': 65,
 'adrenergic receptor agonist': 69,
 'adrenergic receptor antagonist': 15,
 'angiotensin converting enzyme inhibitor': 8,
 'antioxidant': 10,
 'apoptosis stimulant': 20,
 'bacterial 30S ribosomal subunit inhibitor': 13,
 'bacterial 50S ribosomal subunit inhibitor': 17,
 'bacterial DNA gyrase inhibitor': 31,
 'bacterial cell wall synthesis inhibitor': 30,
 'benzodiazepine receptor agonist': 57,
 'bromodomain inhibitor': 59,
 'calcium channel blocker': 35,
 'carbonic anhydrase inhibitor': 50,
 'cyclooxygenase inhibitor': 47,
 'cytochrome P450 inhibitor': 12,
 'dopamine receptor agonist': 54,
 'dopamine receptor antagonist': 14,
 'tachykinin antagonist': 28,
 'estrogen receptor agonist': 52,
 'glucocorticoid receptor agonist': 29,
 'glutamate receptor agonist': 9,
 'glutamate receptor antagonist': 34,
 'histamine receptor agonist': 39,
 'histamine receptor antagonist': 23,
 'histone lysine methyltransferase inhibitor': 21,
 'local anesthetic': 41,
 'mTOR inhibitor': 62,
 'monoamine oxidase inhibitor': 42,
 'nitric oxide synthase inhibitor': 66,
 'opioid receptor agonist': 40,
 'opioid receptor antagonist': 55,
 'p38 MAPK inhibitor': 11,
 'phosphodiesterase inhibitor': 46,
 'potassium channel activator': 1,
 'potassium channel blocker': 68,
 'progesterone receptor agonist': 67,
 'prostanoid receptor antagonist': 48,
 'protein synthesis inhibitor': 25,
 'purinergic receptor antagonist': 61,
 'radiopaque medium': 5,
 'retinoid receptor agonist': 60,
 'rho associated kinase inhibitor': 2,
 'serotonin receptor agonist': 7,
 'serotonin receptor antagonist': 32,
 'sodium channel blocker': 38,
 'topoisomerase inhibitor': 64,
 'tubulin polymerization inhibitor': 24}

# %%
sorted_classes = list(MOA_class_dictionary.values())
sorted_classes.sort() 
assert sorted_classes == [i for i in range(70)]

# %%
# add classes column 
df['classes'] = None
for i in range(df.shape[0]):
  df.iloc[i,2] = MOA_class_dictionary[df.iloc[i,1]]
df
# Out:
#                                                  SMILES  \
# 0                       Oc1ccc(CCNCC2CCc3ccccc3C2=O)cc1
# 1                  OC(CNCCNC(=O)Nc1ccccc1)COc1ccccc1C#N
# 2           O=C1Nc2ccccc2C2=NC(CN3CCN(CC3)c3ccccc3)CN12
# 3            O=C(NC1CCN(CCc2c[nH]c3ccccc23)CC1)c1ccccc1
# 4     O[C@H](CNC[C@@H](O)[C@@H]1CCc2cc(F)ccc2O1)[C@H...
# ...                                                 ...
# 2312  CCn1c(nc2c(ncc(OC[C@H]3CCCNC3)c12)C#CC(C)(C)O)...
# 2313                CCN(CC)CCCCN1c2ccccc2Oc2ccc(Cl)cc12
# 2314      CCCCCCCCCCCCCCCCCCOP(O)(=O)OC1CC[N+](C)(C)CC1
# 2315  Cc1n[nH]c2ccc(cc12)-c1cncc(OC[C@@H](N)Cc2ccccc...
# 2316  CC(C)NC[C@@H](C(=O)N1CCN(CC1)c1ncnc2[C@@H](O)C...
#
#                                  MOA classes
# 0     adrenergic receptor antagonist      15
# 1     adrenergic receptor antagonist      15
# 2     adrenergic receptor antagonist      15
# 3     adrenergic receptor antagonist      15
# 4     adrenergic receptor antagonist      15
# ...                              ...     ...
# 2312                   AKT inhibitor       4
# 2313                   AKT inhibitor       4
# 2314                   AKT inhibitor       4
# 2315                   AKT inhibitor       4
# 2316                   AKT inhibitor       4
#
# [2317 rows x 3 columns]

# %%
# A function that changes smiles string to fingerprints 
import rdkit
import numpy as np
from rdkit import *
from rdkit import Chem, DataStructs
from rdkit.Chem import AllChem
def smiles_to_array_to_string(smiles):
  molecules = Chem.MolFromSmiles(smiles) 
  fingerprints = AllChem.GetMorganFingerprintAsBitVect(molecules, 2)
  x_array = []
  arrays  = np.zeros(0,)
  DataStructs.ConvertToNumpyArray(fingerprints, arrays)
  x_array.append(arrays)
  x_array = np.asarray(x_array)
  x_array = list((np.squeeze(x_array)).astype(int))
  string = ''
  for i in x_array:
    string += str(i) 
  return string

# %%
# Check the existence of Isomers
assert len(set([smiles_to_array_to_string(i) for i in df.SMILES.tolist()])) == df.shape[0]

# %%
# Split out the test set  
from sklearn.model_selection import train_test_split
x_train_valid, x_test, y_train_valid, y_test = train_test_split(df.SMILES, df.classes, test_size =10/100,
 stratify = df.classes, shuffle = True, random_state = 1000)

# %%
# kfold
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits = 9)
skf.get_n_splits(np.array(list(x_train_valid)), np.array(list(y_train_valid)))
train_index_list = []
valid_index_list = []
for train_index, valid_index in skf.split(np.array(list(x_train_valid)), np.array(list(y_train_valid))):
  train_index_list.append(train_index)
  valid_index_list.append(valid_index)

# %%
number_of_kfold = 0 # change the number from 0-8 to get 9 shuffles

# %%
  x_train = list(np.array(list(x_train_valid))[train_index_list[ number_of_kfold ]])
  x_valid = list(np.array(list(x_train_valid))[valid_index_list[ number_of_kfold ]])
  y_train = list(np.array(list(y_train_valid))[train_index_list[ number_of_kfold ]])
  y_valid = list(np.array(list(y_train_valid))[valid_index_list[ number_of_kfold ]])
  x_test = list(x_test)
  y_test = list(y_test)

# %%
# Check if there are overlaps
overlap = []
for i in x_valid:
  if i in x_train:
    overlap.append(i)
    print(i)

# %%
for i in x_test:
  if i in x_train:
    overlap.append(i)
    print(i)

# %%
for i in x_test:
  if i in x_valid:
    overlap.append(i)
    print(i)

# %%
assert len(overlap) == 0

# %%
import gc               
gc.collect()
# Out:
# 327

# %%
x_all = list(x_train) + list(x_valid) + list(x_test)
y_all = list(y_train) + list(y_valid) + list(y_test)

# %%
import pandas as pd
pd_x_all = pd.DataFrame(x_all)
pd_x_all['labels'] = y_all
pd_x_all
# Out:
#                                                       0  labels
# 0     CC[C@H](C)n1cc(C)c2c(cc(cc12)-c1ccc(nc1)N1CCNC...      21
# 1                            CC(=O)Nc1nnc(s1)S(N)(=O)=O      50
# 2     C[C@]12CC[C@H]3[C@@H](CCc4cc(O)ccc34)[C@@H]1C[...      52
# 3                    O=C(COc1cccc2c1cc[nH]c2=O)c1ccccc1      43
# 4     COc1ccc(cc1OC)C(=O)N1CCCc2cc(ccc12)C1=NNC(=O)SC1C      46
# ...                                                 ...     ...
# 2312      CCCc1c(OCCCOc2ccc(OCC(O)=O)cc2)ccc(C(C)=O)c1O      58
# 2313  CO[C@]12C[C@@H](COC(=O)c3cncc(Br)c3)CN(C)[C@@H...      15
# 2314                  CCCN1CCCC[C@H]1C(=O)Nc1c(C)cccc1C      38
# 2315                           CCCC(=O)OCOC(=O)C(C)(C)C      22
# 2316                 Cc1ncc(CN2CCC(=CC2)c2ccccc2)c(N)n1      54
#
# [2317 rows x 2 columns]

# %%
pd_x_all.to_csv('6663.txt', sep = ' ', index = False, header = False,)

# %%
pip install chainer

# %%
import SCFPfunctions as Mf
xp = np 
file = '6663.txt'
smi = Chem.SmilesMolSupplier(file, delimiter=' ', titleLine = False)
mols = [mol for mol in smi if mol is not None]
# Out:
# /usr/local/lib/python3.7/site-packages/chainer/_environment_check.py:75: UserWarning:
# --------------------------------------------------------------------------------
# CuPy (cupy-cuda111) version 9.4.0 may not be compatible with this version of Chainer.
# Please consider installing the supported version by running:
#   $ pip install 'cupy-cuda111>=7.7.0,<8.0.0'
#
# See the following page for more details:
#   https://docs.cupy.dev/en/latest/install.html
# --------------------------------------------------------------------------------
#
#   requirement=requirement, help=help))

# %%
F_list, T_list = [], []
for mol in mols:
  F_list.append(mol_to_feature(mol,-1,500))
  T_list.append(mol.GetProp('_Name'))
 
data_f = xp.asarray(F_list, dtype = xp.float32).reshape(-1, 1, 500, lensize)
data_t = xp.asarray(T_list, dtype = xp.int32).reshape(-1, 1)

dataset = (data_f, data_t)
print(data_t.shape, data_f.shape)
# Out:
# (2317, 1) (2317, 1, 500, 42)

# %%
x, y = dataset[0].T, dataset[1]
x = np.moveaxis(x, -1, 0)
x.shape
# Out:
# (2317, 42, 500, 1)

# %%
import tensorflow as tf
from os import path, getcwd, chdir

# %%
config = tf.compat.v1.ConfigProto()
sess = tf.compat.v1.Session(config = config)

# %%
x_train = x[0:len(x_train)] 
x_valid = x[len(x_train):len(x_train) + len(x_valid)]  
x_test = x[len(x_train) + len(x_valid):len(x_train) + len(x_valid) + len(x_test)]

# %%
y_list = [int(i) for i in y]
Y_train = y_list[0:len(x_train)] 
Y_valid = y_list[len(x_train):len(x_train) + len(x_valid)]  
Y_test = y_list[len(x_train) + len(x_valid):len(x_train) + len(x_valid) + len(x_test)]

# %%
assert np.array_equal(np.array(y_train), np.array(Y_train)) == True
assert np.array_equal(np.array(y_valid), np.array(Y_valid)) == True 
assert np.array_equal(np.array(y_test), np.array(Y_test)) == True

# %%
train_Y = y_train
y_unique = np.unique(np.array(train_Y))
from sklearn.utils import class_weight
class_weights = class_weight.compute_class_weight(class_weight = 'balanced',classes = y_unique,
                       y = np.array(train_Y)) 
class_weights_dict45 = dict(enumerate(class_weights))
class_weights_dict45

# %%
drop = 0.8  
model = tf.keras.models.Sequential([
            tf.keras.layers.Conv2D(8,(3,3),activation='relu',input_shape=(42, 500, 1)),
            tf.keras.layers.MaxPool2D((3,3)),
            tf.keras.layers.Dropout(drop),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dropout(drop),
            tf.keras.layers.Dense(units = len(set(y_list)), activation='softmax')])

# %%
from keras.callbacks import ModelCheckpoint
filepath_cnn = '/content/'+'CNN_70_MOA_weights.hdf5'
checkpoint_cnn = ModelCheckpoint(filepath_cnn, monitor='val_accuracy', verbose=0, save_best_only=True,
              mode='max')

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 1e-3),  
       loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True), 
       metrics = ['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping  
earlyStopping = EarlyStopping(monitor = 'val_loss', patience = 30, verbose = 0, mode = 'min')
reduce_lr_loss = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
           factor = 0.89, patience = 7, verbose = 1, min_delta = 1e-119, mode = 'min')
history = model.fit(x_train, np.array(y_train), validation_data=(x_valid, np.array(y_valid)),
           class_weight = class_weights_dict45, shuffle = True, verbose = 2, epochs = 1800,
           batch_size = 64, callbacks=[earlyStopping, checkpoint_cnn, reduce_lr_loss])
# Out:
# Epoch 1/1800
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 29/29 - 11s - loss: 4.3172 - accuracy: 0.0270 - val_loss: 4.0790 - val_accuracy: 0.0819 - lr: 0.0010 - 11s/epoch - 395ms/step
# Epoch 2/1800
# 29/29 - 0s - loss: 4.2496 - accuracy: 0.0475 - val_loss: 4.0330 - val_accuracy: 0.0948 - lr: 0.0010 - 200ms/epoch - 7ms/step
# Epoch 3/1800
# 29/29 - 0s - loss: 4.1653 - accuracy: 0.0507 - val_loss: 4.0121 - val_accuracy: 0.1034 - lr: 0.0010 - 199ms/epoch - 7ms/step
# Epoch 4/1800
# 29/29 - 0s - loss: 4.1143 - accuracy: 0.0610 - val_loss: 3.9836 - val_accuracy: 0.1121 - lr: 0.0010 - 196ms/epoch - 7ms/step
# Epoch 5/1800
# 29/29 - 0s - loss: 4.0842 - accuracy: 0.0648 - val_loss: 3.9621 - val_accuracy: 0.1207 - lr: 0.0010 - 196ms/epoch - 7ms/step
# Epoch 6/1800
# 29/29 - 0s - loss: 3.9892 - accuracy: 0.0820 - val_loss: 3.9108 - val_accuracy: 0.1250 - lr: 0.0010 - 201ms/epoch - 7ms/step
# Epoch 7/1800
# 29/29 - 0s - loss: 3.9512 - accuracy: 0.0734 - val_loss: 3.8862 - val_accuracy: 0.1293 - lr: 0.0010 - 200ms/epoch - 7ms/step
# Epoch 8/1800
# 29/29 - 0s - loss: 3.9092 - accuracy: 0.0799 - val_loss: 3.8588 - val_accuracy: 0.1379 - lr: 0.0010 - 219ms/epoch - 8ms/step
# Epoch 9/1800
# 29/29 - 0s - loss: 3.8546 - accuracy: 0.0799 - val_loss: 3.8400 - val_accuracy: 0.1422 - lr: 0.0010 - 200ms/epoch - 7ms/step
# Epoch 10/1800
# 29/29 - 0s - loss: 3.8680 - accuracy: 0.0923 - val_loss: 3.8252 - val_accuracy: 0.1638 - lr: 0.0010 - 198ms/epoch - 7ms/step
# Epoch 11/1800
# 29/29 - 0s - loss: 3.7772 - accuracy: 0.1015 - val_loss: 3.8016 - val_accuracy: 0.1422 - lr: 0.0010 - 165ms/epoch - 6ms/step
# Epoch 12/1800
# 29/29 - 0s - loss: 3.7236 - accuracy: 0.0993 - val_loss: 3.7772 - val_accuracy: 0.1466 - lr: 0.0010 - 165ms/epoch - 6ms/step
# Epoch 13/1800
# 29/29 - 0s - loss: 3.7078 - accuracy: 0.1149 - val_loss: 3.7611 - val_accuracy: 0.1509 - lr: 0.0010 - 164ms/epoch - 6ms/step
# Epoch 14/1800
# 29/29 - 0s - loss: 3.6583 - accuracy: 0.1052 - val_loss: 3.7467 - val_accuracy: 0.1552 - lr: 0.0010 - 162ms/epoch - 6ms/step
# Epoch 15/1800
# 29/29 - 0s - loss: 3.6357 - accuracy: 0.1069 - val_loss: 3.7307 - val_accuracy: 0.1724 - lr: 0.0010 - 199ms/epoch - 7ms/step
# Epoch 16/1800
# 29/29 - 0s - loss: 3.5968 - accuracy: 0.1193 - val_loss: 3.7056 - val_accuracy: 0.1724 - lr: 0.0010 - 161ms/epoch - 6ms/step
# Epoch 17/1800
# 29/29 - 0s - loss: 3.6175 - accuracy: 0.1096 - val_loss: 3.7019 - val_accuracy: 0.1681 - lr: 0.0010 - 163ms/epoch - 6ms/step
# Epoch 18/1800
# 29/29 - 0s - loss: 3.5779 - accuracy: 0.1214 - val_loss: 3.6838 - val_accuracy: 0.1638 - lr: 0.0010 - 159ms/epoch - 5ms/step
# Epoch 19/1800
# 29/29 - 0s - loss: 3.5770 - accuracy: 0.1268 - val_loss: 3.6832 - val_accuracy: 0.1681 - lr: 0.0010 - 162ms/epoch - 6ms/step
# Epoch 20/1800
# 29/29 - 0s - loss: 3.5096 - accuracy: 0.1306 - val_loss: 3.6663 - val_accuracy: 0.1810 - lr: 0.0010 - 199ms/epoch - 7ms/step
# Epoch 21/1800
# 29/29 - 0s - loss: 3.5291 - accuracy: 0.1338 - val_loss: 3.6513 - val_accuracy: 0.1853 - lr: 0.0010 - 192ms/epoch - 7ms/step
# Epoch 22/1800
# 29/29 - 0s - loss: 3.4623 - accuracy: 0.1328 - val_loss: 3.6469 - val_accuracy: 0.1638 - lr: 0.0010 - 160ms/epoch - 6ms/step
# Epoch 23/1800
# 29/29 - 0s - loss: 3.4897 - accuracy: 0.1225 - val_loss: 3.6455 - val_accuracy: 0.1767 - lr: 0.0010 - 161ms/epoch - 6ms/step
# Epoch 24/1800
# 29/29 - 0s - loss: 3.4240 - accuracy: 0.1441 - val_loss: 3.6307 - val_accuracy: 0.1810 - lr: 0.0010 - 162ms/epoch - 6ms/step
# Epoch 25/1800
# 29/29 - 0s - loss: 3.3974 - accuracy: 0.1355 - val_loss: 3.6236 - val_accuracy: 0.1897 - lr: 0.0010 - 195ms/epoch - 7ms/step
# Epoch 26/1800
# 29/29 - 0s - loss: 3.4206 - accuracy: 0.1473 - val_loss: 3.6204 - val_accuracy: 0.1810 - lr: 0.0010 - 167ms/epoch - 6ms/step
# Epoch 27/1800
# 29/29 - 0s - loss: 3.3733 - accuracy: 0.1462 - val_loss: 3.6192 - val_accuracy: 0.1767 - lr: 0.0010 - 160ms/epoch - 6ms/step
# Epoch 28/1800
# 29/29 - 0s - loss: 3.3470 - accuracy: 0.1511 - val_loss: 3.6112 - val_accuracy: 0.1767 - lr: 0.0010 - 166ms/epoch - 6ms/step
# Epoch 29/1800
# 29/29 - 0s - loss: 3.3733 - accuracy: 0.1452 - val_loss: 3.6029 - val_accuracy: 0.1853 - lr: 0.0010 - 162ms/epoch - 6ms/step
# Epoch 30/1800
# 29/29 - 0s - loss: 3.3184 - accuracy: 0.1403 - val_loss: 3.5963 - val_accuracy: 0.1681 - lr: 0.0010 - 163ms/epoch - 6ms/step
# Epoch 31/1800
# 29/29 - 0s - loss: 3.3049 - accuracy: 0.1624 - val_loss: 3.5925 - val_accuracy: 0.1853 - lr: 0.0010 - 159ms/epoch - 5ms/step
# Epoch 32/1800
# 29/29 - 0s - loss: 3.2744 - accuracy: 0.1619 - val_loss: 3.5824 - val_accuracy: 0.1897 - lr: 0.0010 - 162ms/epoch - 6ms/step
# Epoch 33/1800
# 29/29 - 0s - loss: 3.3077 - accuracy: 0.1543 - val_loss: 3.5831 - val_accuracy: 0.1810 - lr: 0.0010 - 161ms/epoch - 6ms/step
# Epoch 34/1800
# 29/29 - 0s - loss: 3.2662 - accuracy: 0.1705 - val_loss: 3.5734 - val_accuracy: 0.1940 - lr: 0.0010 - 198ms/epoch - 7ms/step
# Epoch 35/1800
# 29/29 - 0s - loss: 3.2531 - accuracy: 0.1722 - val_loss: 3.5694 - val_accuracy: 0.1810 - lr: 0.0010 - 164ms/epoch - 6ms/step
# Epoch 36/1800
# 29/29 - 0s - loss: 3.2702 - accuracy: 0.1635 - val_loss: 3.5671 - val_accuracy: 0.1853 - lr: 0.0010 - 166ms/epoch - 6ms/step
# Epoch 37/1800
# 29/29 - 0s - loss: 3.2097 - accuracy: 0.1727 - val_loss: 3.5569 - val_accuracy: 0.1983 - lr: 0.0010 - 198ms/epoch - 7ms/step
# Epoch 38/1800
# 29/29 - 0s - loss: 3.2274 - accuracy: 0.1651 - val_loss: 3.5523 - val_accuracy: 0.1940 - lr: 0.0010 - 168ms/epoch - 6ms/step
# Epoch 39/1800
# 29/29 - 0s - loss: 3.1619 - accuracy: 0.1846 - val_loss: 3.5524 - val_accuracy: 0.1853 - lr: 0.0010 - 169ms/epoch - 6ms/step
# Epoch 40/1800
# 29/29 - 0s - loss: 3.1944 - accuracy: 0.1716 - val_loss: 3.5462 - val_accuracy: 0.1724 - lr: 0.0010 - 161ms/epoch - 6ms/step
# Epoch 41/1800
# 29/29 - 0s - loss: 3.1326 - accuracy: 0.1851 - val_loss: 3.5410 - val_accuracy: 0.1810 - lr: 0.0010 - 165ms/epoch - 6ms/step
# Epoch 42/1800
# 29/29 - 0s - loss: 3.1674 - accuracy: 0.1862 - val_loss: 3.5366 - val_accuracy: 0.1897 - lr: 0.0010 - 163ms/epoch - 6ms/step
# Epoch 43/1800
# 29/29 - 0s - loss: 3.1518 - accuracy: 0.1835 - val_loss: 3.5348 - val_accuracy: 0.1853 - lr: 0.0010 - 166ms/epoch - 6ms/step
# Epoch 44/1800
# 29/29 - 0s - loss: 3.1211 - accuracy: 0.1889 - val_loss: 3.5346 - val_accuracy: 0.1897 - lr: 0.0010 - 162ms/epoch - 6ms/step
# Epoch 45/1800
# 29/29 - 0s - loss: 3.2107 - accuracy: 0.1543 - val_loss: 3.5360 - val_accuracy: 0.1853 - lr: 0.0010 - 162ms/epoch - 6ms/step
# Epoch 46/1800
# 29/29 - 0s - loss: 3.1647 - accuracy: 0.1829 - val_loss: 3.5367 - val_accuracy: 0.1940 - lr: 0.0010 - 167ms/epoch - 6ms/step
# Epoch 47/1800
# 29/29 - 0s - loss: 3.1317 - accuracy: 0.1732 - val_loss: 3.5303 - val_accuracy: 0.1940 - lr: 0.0010 - 163ms/epoch - 6ms/step
# Epoch 48/1800
# 29/29 - 0s - loss: 3.1369 - accuracy: 0.1705 - val_loss: 3.5281 - val_accuracy: 0.1983 - lr: 0.0010 - 161ms/epoch - 6ms/step
# Epoch 49/1800
# 29/29 - 0s - loss: 3.0905 - accuracy: 0.1883 - val_loss: 3.5261 - val_accuracy: 0.1983 - lr: 0.0010 - 162ms/epoch - 6ms/step
# Epoch 50/1800
# 29/29 - 0s - loss: 3.1167 - accuracy: 0.1819 - val_loss: 3.5198 - val_accuracy: 0.1897 - lr: 0.0010 - 164ms/epoch - 6ms/step
# Epoch 51/1800
# 29/29 - 0s - loss: 3.1266 - accuracy: 0.1856 - val_loss: 3.5204 - val_accuracy: 0.2069 - lr: 0.0010 - 198ms/epoch - 7ms/step
# Epoch 52/1800
# 29/29 - 0s - loss: 3.1104 - accuracy: 0.1970 - val_loss: 3.5183 - val_accuracy: 0.2026 - lr: 0.0010 - 166ms/epoch - 6ms/step
# Epoch 53/1800
# 29/29 - 0s - loss: 3.0859 - accuracy: 0.1943 - val_loss: 3.5125 - val_accuracy: 0.2026 - lr: 0.0010 - 163ms/epoch - 6ms/step
# Epoch 54/1800
# 29/29 - 0s - loss: 3.0657 - accuracy: 0.1991 - val_loss: 3.5124 - val_accuracy: 0.2026 - lr: 0.0010 - 162ms/epoch - 6ms/step
# Epoch 55/1800
# 29/29 - 0s - loss: 3.0112 - accuracy: 0.1921 - val_loss: 3.5121 - val_accuracy: 0.2155 - lr: 0.0010 - 203ms/epoch - 7ms/step
# Epoch 56/1800
# 29/29 - 0s - loss: 3.0357 - accuracy: 0.2126 - val_loss: 3.5079 - val_accuracy: 0.2026 - lr: 0.0010 - 176ms/epoch - 6ms/step
# Epoch 57/1800
# 29/29 - 0s - loss: 3.0445 - accuracy: 0.1959 - val_loss: 3.5091 - val_accuracy: 0.1940 - lr: 0.0010 - 170ms/epoch - 6ms/step
# Epoch 58/1800
# 29/29 - 0s - loss: 3.0266 - accuracy: 0.1986 - val_loss: 3.5075 - val_accuracy: 0.1940 - lr: 0.0010 - 191ms/epoch - 7ms/step
# Epoch 59/1800
# 29/29 - 0s - loss: 3.0033 - accuracy: 0.2110 - val_loss: 3.5014 - val_accuracy: 0.2112 - lr: 0.0010 - 168ms/epoch - 6ms/step
# Epoch 60/1800
# 29/29 - 0s - loss: 2.9928 - accuracy: 0.2062 - val_loss: 3.5040 - val_accuracy: 0.2069 - lr: 0.0010 - 169ms/epoch - 6ms/step
# Epoch 61/1800
# 29/29 - 0s - loss: 3.0584 - accuracy: 0.1954 - val_loss: 3.5044 - val_accuracy: 0.2069 - lr: 0.0010 - 181ms/epoch - 6ms/step
# Epoch 62/1800
# 29/29 - 0s - loss: 3.0325 - accuracy: 0.2094 - val_loss: 3.5019 - val_accuracy: 0.1983 - lr: 0.0010 - 180ms/epoch - 6ms/step
# Epoch 63/1800
# 29/29 - 0s - loss: 2.9894 - accuracy: 0.2040 - val_loss: 3.4980 - val_accuracy: 0.1983 - lr: 0.0010 - 182ms/epoch - 6ms/step
# Epoch 64/1800
# 29/29 - 0s - loss: 2.9977 - accuracy: 0.2078 - val_loss: 3.5045 - val_accuracy: 0.1983 - lr: 0.0010 - 161ms/epoch - 6ms/step
# Epoch 65/1800
# 29/29 - 0s - loss: 2.9950 - accuracy: 0.2035 - val_loss: 3.4942 - val_accuracy: 0.2026 - lr: 0.0010 - 164ms/epoch - 6ms/step
# Epoch 66/1800
# 29/29 - 0s - loss: 2.9904 - accuracy: 0.2137 - val_loss: 3.4958 - val_accuracy: 0.2069 - lr: 0.0010 - 162ms/epoch - 6ms/step
# Epoch 67/1800
# 29/29 - 0s - loss: 2.9703 - accuracy: 0.2137 - val_loss: 3.4930 - val_accuracy: 0.2069 - lr: 0.0010 - 166ms/epoch - 6ms/step
# Epoch 68/1800
# 29/29 - 0s - loss: 3.0193 - accuracy: 0.2105 - val_loss: 3.4951 - val_accuracy: 0.2069 - lr: 0.0010 - 165ms/epoch - 6ms/step
# Epoch 69/1800
# 29/29 - 0s - loss: 2.9693 - accuracy: 0.2132 - val_loss: 3.4897 - val_accuracy: 0.2069 - lr: 0.0010 - 163ms/epoch - 6ms/step
# Epoch 70/1800
# 29/29 - 0s - loss: 2.9091 - accuracy: 0.2148 - val_loss: 3.4909 - val_accuracy: 0.1983 - lr: 0.0010 - 162ms/epoch - 6ms/step
# Epoch 71/1800
# 29/29 - 0s - loss: 2.9212 - accuracy: 0.2045 - val_loss: 3.4898 - val_accuracy: 0.1983 - lr: 0.0010 - 157ms/epoch - 5ms/step
# Epoch 72/1800
# 29/29 - 0s - loss: 2.9462 - accuracy: 0.1986 - val_loss: 3.4851 - val_accuracy: 0.2026 - lr: 0.0010 - 166ms/epoch - 6ms/step
# Epoch 73/1800
# 29/29 - 0s - loss: 2.9511 - accuracy: 0.2142 - val_loss: 3.4895 - val_accuracy: 0.2026 - lr: 0.0010 - 159ms/epoch - 5ms/step
# Epoch 74/1800
# 29/29 - 0s - loss: 2.9396 - accuracy: 0.2153 - val_loss: 3.4929 - val_accuracy: 0.2112 - lr: 0.0010 - 162ms/epoch - 6ms/step
# Epoch 75/1800
# 29/29 - 0s - loss: 2.8994 - accuracy: 0.2277 - val_loss: 3.4876 - val_accuracy: 0.2112 - lr: 0.0010 - 161ms/epoch - 6ms/step
# Epoch 76/1800
# 29/29 - 0s - loss: 2.9784 - accuracy: 0.2062 - val_loss: 3.4819 - val_accuracy: 0.2069 - lr: 0.0010 - 159ms/epoch - 5ms/step
# Epoch 77/1800
# 29/29 - 0s - loss: 2.8798 - accuracy: 0.2234 - val_loss: 3.4819 - val_accuracy: 0.2112 - lr: 0.0010 - 162ms/epoch - 6ms/step
# Epoch 78/1800
# 29/29 - 0s - loss: 2.8894 - accuracy: 0.2299 - val_loss: 3.4855 - val_accuracy: 0.2026 - lr: 0.0010 - 160ms/epoch - 6ms/step
# Epoch 79/1800
# 29/29 - 0s - loss: 2.9126 - accuracy: 0.2202 - val_loss: 3.4773 - val_accuracy: 0.2069 - lr: 0.0010 - 162ms/epoch - 6ms/step
# Epoch 80/1800
# 29/29 - 0s - loss: 2.8494 - accuracy: 0.2321 - val_loss: 3.4765 - val_accuracy: 0.2026 - lr: 0.0010 - 157ms/epoch - 5ms/step
# Epoch 81/1800
# 29/29 - 0s - loss: 2.8513 - accuracy: 0.2202 - val_loss: 3.4789 - val_accuracy: 0.2069 - lr: 0.0010 - 162ms/epoch - 6ms/step
# Epoch 82/1800
# 29/29 - 0s - loss: 2.8876 - accuracy: 0.2223 - val_loss: 3.4803 - val_accuracy: 0.2198 - lr: 0.0010 - 200ms/epoch - 7ms/step
# Epoch 83/1800
# 29/29 - 0s - loss: 2.8876 - accuracy: 0.2288 - val_loss: 3.4800 - val_accuracy: 0.2241 - lr: 0.0010 - 196ms/epoch - 7ms/step
# Epoch 84/1800
# 29/29 - 0s - loss: 2.8404 - accuracy: 0.2099 - val_loss: 3.4771 - val_accuracy: 0.2198 - lr: 0.0010 - 161ms/epoch - 6ms/step
# Epoch 85/1800
# 29/29 - 0s - loss: 2.8267 - accuracy: 0.2202 - val_loss: 3.4835 - val_accuracy: 0.2155 - lr: 0.0010 - 163ms/epoch - 6ms/step
# Epoch 86/1800
# 29/29 - 0s - loss: 2.8581 - accuracy: 0.2218 - val_loss: 3.4792 - val_accuracy: 0.1983 - lr: 0.0010 - 160ms/epoch - 6ms/step
# Epoch 87/1800
# 29/29 - 0s - loss: 2.8452 - accuracy: 0.2223 - val_loss: 3.4759 - val_accuracy: 0.2069 - lr: 0.0010 - 162ms/epoch - 6ms/step
# Epoch 88/1800
# 29/29 - 0s - loss: 2.8381 - accuracy: 0.2337 - val_loss: 3.4796 - val_accuracy: 0.2112 - lr: 0.0010 - 161ms/epoch - 6ms/step
# Epoch 89/1800
# 29/29 - 0s - loss: 2.8966 - accuracy: 0.2267 - val_loss: 3.4748 - val_accuracy: 0.2069 - lr: 0.0010 - 159ms/epoch - 5ms/step
# Epoch 90/1800
# 29/29 - 0s - loss: 2.8392 - accuracy: 0.2331 - val_loss: 3.4841 - val_accuracy: 0.2069 - lr: 0.0010 - 161ms/epoch - 6ms/step
# Epoch 91/1800
# 29/29 - 0s - loss: 2.8746 - accuracy: 0.2191 - val_loss: 3.4862 - val_accuracy: 0.2112 - lr: 0.0010 - 159ms/epoch - 5ms/step
# Epoch 92/1800
# 29/29 - 0s - loss: 2.7878 - accuracy: 0.2326 - val_loss: 3.4862 - val_accuracy: 0.2069 - lr: 0.0010 - 157ms/epoch - 5ms/step
# Epoch 93/1800
# 29/29 - 0s - loss: 2.8086 - accuracy: 0.2299 - val_loss: 3.4811 - val_accuracy: 0.2241 - lr: 0.0010 - 164ms/epoch - 6ms/step
# Epoch 94/1800
# 29/29 - 0s - loss: 2.8475 - accuracy: 0.2299 - val_loss: 3.4731 - val_accuracy: 0.2284 - lr: 0.0010 - 205ms/epoch - 7ms/step
# Epoch 95/1800
# 29/29 - 0s - loss: 2.7915 - accuracy: 0.2472 - val_loss: 3.4808 - val_accuracy: 0.2241 - lr: 0.0010 - 164ms/epoch - 6ms/step
# Epoch 96/1800
# 29/29 - 0s - loss: 2.7463 - accuracy: 0.2428 - val_loss: 3.4788 - val_accuracy: 0.2112 - lr: 0.0010 - 162ms/epoch - 6ms/step
# Epoch 97/1800
# 29/29 - 0s - loss: 2.8098 - accuracy: 0.2267 - val_loss: 3.4783 - val_accuracy: 0.2241 - lr: 0.0010 - 161ms/epoch - 6ms/step
# Epoch 98/1800
# 29/29 - 0s - loss: 2.7910 - accuracy: 0.2407 - val_loss: 3.4731 - val_accuracy: 0.2198 - lr: 0.0010 - 168ms/epoch - 6ms/step
# Epoch 99/1800
# 29/29 - 0s - loss: 2.8502 - accuracy: 0.2229 - val_loss: 3.4710 - val_accuracy: 0.2155 - lr: 0.0010 - 160ms/epoch - 6ms/step
# Epoch 100/1800
# 29/29 - 0s - loss: 2.7930 - accuracy: 0.2412 - val_loss: 3.4723 - val_accuracy: 0.2284 - lr: 0.0010 - 158ms/epoch - 5ms/step
# Epoch 101/1800
# 29/29 - 0s - loss: 2.7653 - accuracy: 0.2482 - val_loss: 3.4790 - val_accuracy: 0.2284 - lr: 0.0010 - 163ms/epoch - 6ms/step
# Epoch 102/1800
# 29/29 - 0s - loss: 2.7673 - accuracy: 0.2358 - val_loss: 3.4820 - val_accuracy: 0.2328 - lr: 0.0010 - 201ms/epoch - 7ms/step
# Epoch 103/1800
# 29/29 - 0s - loss: 2.7750 - accuracy: 0.2396 - val_loss: 3.4764 - val_accuracy: 0.2241 - lr: 0.0010 - 166ms/epoch - 6ms/step
# Epoch 104/1800
# 29/29 - 0s - loss: 2.7564 - accuracy: 0.2412 - val_loss: 3.4777 - val_accuracy: 0.2284 - lr: 0.0010 - 161ms/epoch - 6ms/step
# Epoch 105/1800
# 29/29 - 0s - loss: 2.7882 - accuracy: 0.2213 - val_loss: 3.4780 - val_accuracy: 0.2198 - lr: 0.0010 - 160ms/epoch - 6ms/step
# Epoch 106/1800
#
# Epoch 106: ReduceLROnPlateau reducing learning rate to 0.0008900000422727317.
# 29/29 - 0s - loss: 2.7708 - accuracy: 0.2331 - val_loss: 3.4718 - val_accuracy: 0.2198 - lr: 0.0010 - 163ms/epoch - 6ms/step
# Epoch 107/1800
# 29/29 - 0s - loss: 2.7798 - accuracy: 0.2348 - val_loss: 3.4685 - val_accuracy: 0.2198 - lr: 8.9000e-04 - 160ms/epoch - 6ms/step
# Epoch 108/1800
# 29/29 - 0s - loss: 2.7665 - accuracy: 0.2412 - val_loss: 3.4730 - val_accuracy: 0.2284 - lr: 8.9000e-04 - 161ms/epoch - 6ms/step
# Epoch 109/1800
# 29/29 - 0s - loss: 2.7404 - accuracy: 0.2326 - val_loss: 3.4757 - val_accuracy: 0.2284 - lr: 8.9000e-04 - 161ms/epoch - 6ms/step
# Epoch 110/1800
# 29/29 - 0s - loss: 2.7405 - accuracy: 0.2455 - val_loss: 3.4727 - val_accuracy: 0.2241 - lr: 8.9000e-04 - 164ms/epoch - 6ms/step
# Epoch 111/1800
# 29/29 - 0s - loss: 2.7489 - accuracy: 0.2439 - val_loss: 3.4733 - val_accuracy: 0.2112 - lr: 8.9000e-04 - 165ms/epoch - 6ms/step
# Epoch 112/1800
# 29/29 - 0s - loss: 2.7523 - accuracy: 0.2423 - val_loss: 3.4737 - val_accuracy: 0.2112 - lr: 8.9000e-04 - 169ms/epoch - 6ms/step
# Epoch 113/1800
# 29/29 - 0s - loss: 2.7264 - accuracy: 0.2412 - val_loss: 3.4739 - val_accuracy: 0.2198 - lr: 8.9000e-04 - 165ms/epoch - 6ms/step
# Epoch 114/1800
#
# Epoch 114: ReduceLROnPlateau reducing learning rate to 0.0007921000220812857.
# 29/29 - 0s - loss: 2.7376 - accuracy: 0.2466 - val_loss: 3.4701 - val_accuracy: 0.2198 - lr: 8.9000e-04 - 167ms/epoch - 6ms/step
# Epoch 115/1800
# 29/29 - 0s - loss: 2.6706 - accuracy: 0.2455 - val_loss: 3.4719 - val_accuracy: 0.2241 - lr: 7.9210e-04 - 166ms/epoch - 6ms/step
# Epoch 116/1800
# 29/29 - 0s - loss: 2.7705 - accuracy: 0.2358 - val_loss: 3.4737 - val_accuracy: 0.2155 - lr: 7.9210e-04 - 168ms/epoch - 6ms/step
# Epoch 117/1800
# 29/29 - 0s - loss: 2.7750 - accuracy: 0.2348 - val_loss: 3.4692 - val_accuracy: 0.2155 - lr: 7.9210e-04 - 167ms/epoch - 6ms/step
# Epoch 118/1800
# 29/29 - 0s - loss: 2.7294 - accuracy: 0.2488 - val_loss: 3.4718 - val_accuracy: 0.2241 - lr: 7.9210e-04 - 164ms/epoch - 6ms/step
# Epoch 119/1800
# 29/29 - 0s - loss: 2.8078 - accuracy: 0.2304 - val_loss: 3.4666 - val_accuracy: 0.2198 - lr: 7.9210e-04 - 161ms/epoch - 6ms/step
# Epoch 120/1800
# 29/29 - 0s - loss: 2.7320 - accuracy: 0.2553 - val_loss: 3.4685 - val_accuracy: 0.2284 - lr: 7.9210e-04 - 163ms/epoch - 6ms/step
# Epoch 121/1800
# 29/29 - 0s - loss: 2.7217 - accuracy: 0.2585 - val_loss: 3.4725 - val_accuracy: 0.2284 - lr: 7.9210e-04 - 164ms/epoch - 6ms/step
# Epoch 122/1800
# 29/29 - 0s - loss: 2.7507 - accuracy: 0.2418 - val_loss: 3.4744 - val_accuracy: 0.2198 - lr: 7.9210e-04 - 163ms/epoch - 6ms/step
# Epoch 123/1800
# 29/29 - 0s - loss: 2.7191 - accuracy: 0.2445 - val_loss: 3.4665 - val_accuracy: 0.2328 - lr: 7.9210e-04 - 164ms/epoch - 6ms/step
# Epoch 124/1800
# 29/29 - 0s - loss: 2.6900 - accuracy: 0.2585 - val_loss: 3.4705 - val_accuracy: 0.2284 - lr: 7.9210e-04 - 169ms/epoch - 6ms/step
# Epoch 125/1800
# 29/29 - 0s - loss: 2.6890 - accuracy: 0.2601 - val_loss: 3.4674 - val_accuracy: 0.2414 - lr: 7.9210e-04 - 204ms/epoch - 7ms/step
# Epoch 126/1800
# 29/29 - 0s - loss: 2.6756 - accuracy: 0.2526 - val_loss: 3.4637 - val_accuracy: 0.2328 - lr: 7.9210e-04 - 172ms/epoch - 6ms/step
# Epoch 127/1800
# 29/29 - 0s - loss: 2.7028 - accuracy: 0.2482 - val_loss: 3.4704 - val_accuracy: 0.2284 - lr: 7.9210e-04 - 166ms/epoch - 6ms/step
# Epoch 128/1800
# 29/29 - 0s - loss: 2.7545 - accuracy: 0.2445 - val_loss: 3.4671 - val_accuracy: 0.2328 - lr: 7.9210e-04 - 163ms/epoch - 6ms/step
# Epoch 129/1800
# 29/29 - 0s - loss: 2.7374 - accuracy: 0.2536 - val_loss: 3.4619 - val_accuracy: 0.2371 - lr: 7.9210e-04 - 167ms/epoch - 6ms/step
# Epoch 130/1800
# 29/29 - 0s - loss: 2.6880 - accuracy: 0.2623 - val_loss: 3.4662 - val_accuracy: 0.2371 - lr: 7.9210e-04 - 166ms/epoch - 6ms/step
# Epoch 131/1800
# 29/29 - 0s - loss: 2.6568 - accuracy: 0.2509 - val_loss: 3.4614 - val_accuracy: 0.2328 - lr: 7.9210e-04 - 164ms/epoch - 6ms/step
# Epoch 132/1800
# 29/29 - 0s - loss: 2.7214 - accuracy: 0.2504 - val_loss: 3.4615 - val_accuracy: 0.2328 - lr: 7.9210e-04 - 166ms/epoch - 6ms/step
# Epoch 133/1800
# 29/29 - 0s - loss: 2.7152 - accuracy: 0.2326 - val_loss: 3.4598 - val_accuracy: 0.2328 - lr: 7.9210e-04 - 166ms/epoch - 6ms/step
# Epoch 134/1800
# 29/29 - 0s - loss: 2.6588 - accuracy: 0.2493 - val_loss: 3.4645 - val_accuracy: 0.2241 - lr: 7.9210e-04 - 167ms/epoch - 6ms/step
# Epoch 135/1800
# 29/29 - 0s - loss: 2.6398 - accuracy: 0.2634 - val_loss: 3.4657 - val_accuracy: 0.2328 - lr: 7.9210e-04 - 163ms/epoch - 6ms/step
# Epoch 136/1800
# 29/29 - 0s - loss: 2.6131 - accuracy: 0.2655 - val_loss: 3.4652 - val_accuracy: 0.2414 - lr: 7.9210e-04 - 164ms/epoch - 6ms/step
# Epoch 137/1800
# 29/29 - 0s - loss: 2.6346 - accuracy: 0.2704 - val_loss: 3.4725 - val_accuracy: 0.2414 - lr: 7.9210e-04 - 164ms/epoch - 6ms/step
# Epoch 138/1800
# 29/29 - 0s - loss: 2.6624 - accuracy: 0.2547 - val_loss: 3.4768 - val_accuracy: 0.2371 - lr: 7.9210e-04 - 165ms/epoch - 6ms/step
# Epoch 139/1800
# 29/29 - 0s - loss: 2.6313 - accuracy: 0.2666 - val_loss: 3.4760 - val_accuracy: 0.2328 - lr: 7.9210e-04 - 163ms/epoch - 6ms/step
# Epoch 140/1800
#
# Epoch 140: ReduceLROnPlateau reducing learning rate to 0.0007049690320855007.
# 29/29 - 0s - loss: 2.6312 - accuracy: 0.2601 - val_loss: 3.4712 - val_accuracy: 0.2328 - lr: 7.9210e-04 - 168ms/epoch - 6ms/step
# Epoch 141/1800
# 29/29 - 0s - loss: 2.6401 - accuracy: 0.2655 - val_loss: 3.4721 - val_accuracy: 0.2328 - lr: 7.0497e-04 - 161ms/epoch - 6ms/step
# Epoch 142/1800
# 29/29 - 0s - loss: 2.6691 - accuracy: 0.2493 - val_loss: 3.4699 - val_accuracy: 0.2414 - lr: 7.0497e-04 - 164ms/epoch - 6ms/step
# Epoch 143/1800
# 29/29 - 0s - loss: 2.6603 - accuracy: 0.2574 - val_loss: 3.4671 - val_accuracy: 0.2457 - lr: 7.0497e-04 - 200ms/epoch - 7ms/step
# Epoch 144/1800
# 29/29 - 0s - loss: 2.5965 - accuracy: 0.2655 - val_loss: 3.4710 - val_accuracy: 0.2414 - lr: 7.0497e-04 - 164ms/epoch - 6ms/step
# Epoch 145/1800
# 29/29 - 0s - loss: 2.6481 - accuracy: 0.2612 - val_loss: 3.4742 - val_accuracy: 0.2457 - lr: 7.0497e-04 - 162ms/epoch - 6ms/step
# Epoch 146/1800
# 29/29 - 0s - loss: 2.6709 - accuracy: 0.2563 - val_loss: 3.4774 - val_accuracy: 0.2414 - lr: 7.0497e-04 - 165ms/epoch - 6ms/step
# Epoch 147/1800
#
# Epoch 147: ReduceLROnPlateau reducing learning rate to 0.0006274224515073002.
# 29/29 - 0s - loss: 2.6546 - accuracy: 0.2553 - val_loss: 3.4755 - val_accuracy: 0.2457 - lr: 7.0497e-04 - 164ms/epoch - 6ms/step
# Epoch 148/1800
# 29/29 - 0s - loss: 2.6806 - accuracy: 0.2617 - val_loss: 3.4788 - val_accuracy: 0.2328 - lr: 6.2742e-04 - 164ms/epoch - 6ms/step
# Epoch 149/1800
# 29/29 - 0s - loss: 2.6352 - accuracy: 0.2563 - val_loss: 3.4764 - val_accuracy: 0.2414 - lr: 6.2742e-04 - 167ms/epoch - 6ms/step
# Epoch 150/1800
# 29/29 - 0s - loss: 2.6532 - accuracy: 0.2536 - val_loss: 3.4800 - val_accuracy: 0.2457 - lr: 6.2742e-04 - 166ms/epoch - 6ms/step
# Epoch 151/1800
# 29/29 - 0s - loss: 2.5971 - accuracy: 0.2563 - val_loss: 3.4799 - val_accuracy: 0.2457 - lr: 6.2742e-04 - 163ms/epoch - 6ms/step
# Epoch 152/1800
# 29/29 - 0s - loss: 2.6159 - accuracy: 0.2590 - val_loss: 3.4759 - val_accuracy: 0.2457 - lr: 6.2742e-04 - 165ms/epoch - 6ms/step
# Epoch 153/1800
# 29/29 - 0s - loss: 2.6026 - accuracy: 0.2553 - val_loss: 3.4775 - val_accuracy: 0.2457 - lr: 6.2742e-04 - 164ms/epoch - 6ms/step
# Epoch 154/1800
#
# Epoch 154: ReduceLROnPlateau reducing learning rate to 0.0005584060004912317.
# 29/29 - 0s - loss: 2.6305 - accuracy: 0.2574 - val_loss: 3.4756 - val_accuracy: 0.2457 - lr: 6.2742e-04 - 167ms/epoch - 6ms/step
# Epoch 155/1800
# 29/29 - 0s - loss: 2.7213 - accuracy: 0.2628 - val_loss: 3.4674 - val_accuracy: 0.2500 - lr: 5.5841e-04 - 201ms/epoch - 7ms/step
# Epoch 156/1800
# 29/29 - 0s - loss: 2.6398 - accuracy: 0.2445 - val_loss: 3.4666 - val_accuracy: 0.2500 - lr: 5.5841e-04 - 166ms/epoch - 6ms/step
# Epoch 157/1800
# 29/29 - 0s - loss: 2.5990 - accuracy: 0.2639 - val_loss: 3.4723 - val_accuracy: 0.2414 - lr: 5.5841e-04 - 164ms/epoch - 6ms/step
# Epoch 158/1800
# 29/29 - 0s - loss: 2.6260 - accuracy: 0.2531 - val_loss: 3.4767 - val_accuracy: 0.2414 - lr: 5.5841e-04 - 174ms/epoch - 6ms/step
# Epoch 159/1800
# 29/29 - 0s - loss: 2.5832 - accuracy: 0.2790 - val_loss: 3.4790 - val_accuracy: 0.2414 - lr: 5.5841e-04 - 168ms/epoch - 6ms/step
# Epoch 160/1800
# 29/29 - 0s - loss: 2.5689 - accuracy: 0.2628 - val_loss: 3.4801 - val_accuracy: 0.2457 - lr: 5.5841e-04 - 164ms/epoch - 6ms/step
# Epoch 161/1800
#
# Epoch 161: ReduceLROnPlateau reducing learning rate to 0.0004969813383650035.
# 29/29 - 0s - loss: 2.6132 - accuracy: 0.2612 - val_loss: 3.4802 - val_accuracy: 0.2543 - lr: 5.5841e-04 - 205ms/epoch - 7ms/step
# Epoch 162/1800
# 29/29 - 0s - loss: 2.5885 - accuracy: 0.2720 - val_loss: 3.4808 - val_accuracy: 0.2500 - lr: 4.9698e-04 - 176ms/epoch - 6ms/step
# Epoch 163/1800
# 29/29 - 0s - loss: 2.6773 - accuracy: 0.2526 - val_loss: 3.4787 - val_accuracy: 0.2543 - lr: 4.9698e-04 - 164ms/epoch - 6ms/step

# %%
from keras.models import load_model
best_model = load_model(filepath_cnn)

# %%
# Evaluate the model 
from sklearn.metrics import classification_report
assert list(y_test)[0:5] ==  [10, 47, 20, 23, 25]
print(classification_report(y_valid, np.array(best_model.predict(x_valid).argmax(-1)),))
print(classification_report(y_test, np.array(best_model.predict(x_test).argmax(-1)),))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.25      0.50      0.33         2
#            1       0.00      0.00      0.00         2
#            2       0.00      0.00      0.00         2
#            3       0.00      0.00      0.00         2
#            4       1.00      1.00      1.00         1
#            5       0.33      0.50      0.40         2
#            6       0.00      0.00      0.00         2
#            7       0.00      0.00      0.00         6
#            8       0.50      0.33      0.40         3
#            9       0.00      0.00      0.00         3
#           10       0.00      0.00      0.00         3
#           11       0.14      0.50      0.22         2
#           12       0.00      0.00      0.00         3
#           13       0.67      0.67      0.67         3
#           14       0.20      0.33      0.25         6
#           15       0.80      0.44      0.57         9
#           16       0.20      0.50      0.29         2
#           17       1.00      1.00      1.00         2
#           18       0.33      0.67      0.44         3
#           19       0.00      0.00      0.00         2
#           20       0.00      0.00      0.00         2
#           21       0.50      0.50      0.50         2
#           22       0.00      0.00      0.00         4
#           23       0.14      0.29      0.19         7
#           24       0.00      0.00      0.00         3
#           25       0.00      0.00      0.00         4
#           26       0.00      0.00      0.00         2
#           27       0.00      0.00      0.00         2
#           28       0.50      0.50      0.50         2
#           29       0.38      0.75      0.50         4
#           30       0.73      0.80      0.76        10
#           31       0.50      0.33      0.40         3
#           32       0.17      0.29      0.21         7
#           33       0.00      0.00      0.00         3
#           34       0.17      0.14      0.15         7
#           35       0.00      0.00      0.00         4
#           36       0.50      0.22      0.31         9
#           37       0.00      0.00      0.00         2
#           38       0.00      0.00      0.00         4
#           39       0.00      0.00      0.00         2
#           40       0.50      0.50      0.50         2
#           41       0.00      0.00      0.00         2
#           42       0.06      0.33      0.10         3
#           43       0.00      0.00      0.00         2
#           44       0.15      0.50      0.24         4
#           45       0.50      0.50      0.50         2
#           46       0.00      0.00      0.00         6
#           47       0.30      0.33      0.32         9
#           48       0.00      0.00      0.00         2
#           49       0.00      0.00      0.00         2
#           50       0.50      1.00      0.67         1
#           51       0.00      0.00      0.00         4
#           52       0.00      0.00      0.00         2
#           53       0.33      0.50      0.40         4
#           54       0.33      0.25      0.29         4
#           55       1.00      0.50      0.67         2
#           56       0.00      0.00      0.00         2
#           57       0.00      0.00      0.00         3
#           58       0.00      0.00      0.00         2
#           59       0.25      0.50      0.33         2
#           60       0.50      0.50      0.50         2
#           61       0.00      0.00      0.00         2
#           62       0.00      0.00      0.00         2
#           63       0.33      0.50      0.40         2
#           64       0.00      0.00      0.00         4
#           65       0.33      0.50      0.40         2
#           66       0.12      0.50      0.20         2
#           67       0.25      0.50      0.33         2
#           68       0.00      0.00      0.00         3
#           69       0.33      0.12      0.18         8
#
#     accuracy                           0.25       232
#    macro avg       0.21      0.25      0.22       232
# weighted avg       0.24      0.25      0.23       232
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.20      0.50      0.29         2
#            2       0.00      0.00      0.00         2
#            3       0.00      0.00      0.00         2
#            4       0.00      0.00      0.00         2
#            5       0.50      0.50      0.50         2
#            6       0.00      0.00      0.00         2
#            7       0.67      0.33      0.44         6
#            8       1.00      1.00      1.00         2
#            9       0.00      0.00      0.00         3
#           10       0.00      0.00      0.00         2
#           11       0.00      0.00      0.00         2
#           12       0.00      0.00      0.00         2
#           13       0.00      0.00      0.00         2
#           14       0.17      0.33      0.22         6
#           15       0.00      0.00      0.00        10
#           16       0.25      0.50      0.33         2
#           17       0.00      0.00      0.00         2
#           18       0.00      0.00      0.00         3
#           19       0.00      0.00      0.00         2
#           20       0.00      0.00      0.00         2
#           21       1.00      0.67      0.80         3
#           22       0.50      0.25      0.33         4
#           23       0.22      0.29      0.25         7
#           24       0.00      0.00      0.00         2
#           25       0.33      0.25      0.29         4
#           26       0.00      0.00      0.00         2
#           27       0.00      0.00      0.00         2
#           28       0.00      0.00      0.00         1
#           29       0.62      1.00      0.77         5
#           30       0.80      0.80      0.80        10
#           31       0.17      0.33      0.22         3
#           32       0.00      0.00      0.00         7
#           33       0.00      0.00      0.00         3
#           34       0.00      0.00      0.00         7
#           35       1.00      0.40      0.57         5
#           36       0.50      0.25      0.33         8
#           37       0.00      0.00      0.00         2
#           38       0.00      0.00      0.00         4
#           39       0.00      0.00      0.00         2
#           40       0.00      0.00      0.00         2
#           41       0.67      1.00      0.80         2
#           42       0.10      0.33      0.15         3
#           43       0.00      0.00      0.00         2
#           44       0.13      0.50      0.21         4
#           45       0.00      0.00      0.00         2
#           46       0.33      0.33      0.33         6
#           47       0.17      0.10      0.12        10
#           48       0.00      0.00      0.00         2
#           49       0.00      0.00      0.00         2
#           50       0.33      0.50      0.40         2
#           51       0.20      0.25      0.22         4
#           52       0.00      0.00      0.00         2
#           53       0.00      0.00      0.00         4
#           54       0.00      0.00      0.00         4
#           55       0.00      0.00      0.00         2
#           56       0.00      0.00      0.00         2
#           57       0.00      0.00      0.00         3
#           58       0.00      0.00      0.00         2
#           59       0.00      0.00      0.00         2
#           60       0.50      0.50      0.50         2
#           61       0.00      0.00      0.00         2
#           62       0.00      0.00      0.00         2
#           63       0.00      0.00      0.00         2
#           64       0.25      0.25      0.25         4
#           65       0.00      0.00      0.00         3
#           66       0.00      0.00      0.00         2
#           67       0.50      0.50      0.50         2
#           68       0.00      0.00      0.00         2
#           69       0.25      0.12      0.17         8
#
#     accuracy                           0.20       232
#    macro avg       0.16      0.17      0.15       232
# weighted avg       0.21      0.20      0.19       232
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Training curves
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc = 'upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc = 'upper left')
plt.show()

# %%
# References 
# http://www.dna.bio.keio.ac.jp/smiles/
# https://github.com/pharmbio/dl_quantmap/tree/master/cross_validation/CNN
